# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Anu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("PS4_GamesSales.csv", encoding = 'latin-1')

# %%
print(df.isnull().sum())
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
df['Publisher'] = df['Publisher'].fillna('Unknown')

# %%
df['Year'] = df['Year'].fillna(2012)

# %%
print(df.isnull().sum())
# Out:
# Game             0
# Year             0
# Genre            0
# Publisher        0
# North America    0
# Europe           0
# Japan            0
# Rest of World    0
# Global           0
# dtype: int64

# %%
#Basic Bar Plot

plt.figure(figsize=(10,6))
plt.bar(df['Genre'], df['Global'])
plt.title("basic plot")
plt.xlabel("Games")
plt.ylabel("Sales")
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.savefig("My_Chart.png")
plt.show()

# %%
#Basic Line plot sales Trend over year

sales_by_year = df.groupby('Year')['Global'].sum().sort_index()

plt.Figure(figsize=(8,5))
plt.plot(sales_by_year.index, sales_by_year.values,marker='o')
plt.title("Total Global Sales by Year")
plt.xlabel("Year")
plt.ylabel("Global Sales")
plt.grid(True)
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
genre_sales = df.groupby('Genre')['Global'].sum()
print(genre_sales)

explode = [0.2 if year == 2015 else 0 for year in sales_by_year.index]
colors_pie = ["#A86658", "#C4F03E", "#D38338", "#45E8C8", "#38B138", "#A46CAB", "#E68888", "#E1EDBE"]

plt.pie(sales_by_year, labels=sales_by_year.index, autopct='%1.1f%%', colors=colors_pie, startangle=35, shadow=True,explode=explode)
plt.title("Global Sales by Year")
plt.axis('equal')
plt.tight_layout()
plt.show()
# Out:
# Genre
# Action              136.85
# Action-Adventure     61.86
# Adventure            15.22
# Fighting             19.46
# MMO                   3.52
# Misc                 12.47
# Music                 5.03
# Party                 0.65
# Platform             17.85
# Puzzle                0.52
# Racing               25.29
# Role-Playing         62.82
# Shooter             134.99
# Simulation            4.52
# Sports               92.85
# Strategy              1.28
# Visual Novel          0.46
# Name: Global, dtype: float64
